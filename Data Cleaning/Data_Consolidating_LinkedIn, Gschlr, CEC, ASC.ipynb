# %%
import pandas as pd
import os
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
import re
nltk.download()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\munna\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
os.getcwd()
# Out:
# 'C:\\Users\\munna'

# %%
os.chdir(r'C:\Users\munna\Desktop\Final Project\Sprint 3\DATA COMBINING\Work 1')

# %%
# reading two csv files
data1 = pd.read_csv(r'C:\Users\munna\Desktop\Final Project\Sprint 3\DATA COMBINING\Work 1\merge.csv')
data2 = pd.read_csv(r'C:\Users\munna\Desktop\Final Project\Sprint 3\DATA COMBINING\Work 1\LinkedIn_Final.csv')

# %%
data2['authors'].str.lower()
df1 = pd.DataFrame(data2, columns = ['authors'])

# %%
data2['authors'] = df1['authors'].str.lower()

# %%
data2
# Out:
#      Unnamed: 0                authors  \
# 0             0  massimiliano albanese
# 1             1  massimiliano albanese
# 2             2  massimiliano albanese
# 3             3  massimiliano albanese
# 4             4  massimiliano albanese
# ..          ...                    ...
# 369         369            ningshi yao
# 370         370            ningshi yao
# 371         371            ningshi yao
# 372         372            ningshi yao
# 373         373            ningshi yao
#
#                                                  Title  \
# 0    Poster: Securing Distributed System Configurat...
# 1    DeBot: A Novel Network-based Mechanism to Dete...
# 2    From Cyber Situational Awareness to Adaptive C...
# 3    A Quantitative Framework to Model Advanced Per...
# 4    Defending from Stealthy Botnets Using Moving T...
# ..                                                 ...
# 369  Resolving Contentions for Intelligent Traffic ...
# ...

# %%
data3 = pd.read_csv(r'C:\Users\munna\Desktop\Final Project\Sprint 3\DATA COMBINING\Work 1\LinkedIn_Final.csv')

# %%
data3['Descriptions'] = data3['Descriptions'].str.lower()# Converting Uppercase letters to Lower case
data3['About'] = data3['About'].str.lower()
data4['Descriptions'] = data3['Descriptions'].str.replace('\W', ' ', regex=True)# Removing special characters
data3['Descriptions'] = data4['Descriptions'].str.replace('-', ' ')

# %%
data3
# Out:
#      Unnamed: 0                authors  \
# 0             0  massimiliano albanese
# 1             1  massimiliano albanese
# 2             2  massimiliano albanese
# 3             3  massimiliano albanese
# 4             4  massimiliano albanese
# ..          ...                    ...
# 369         369            ningshi yao
# 370         370            ningshi yao
# 371         371            ningshi yao
# 372         372            ningshi yao
# 373         373            ningshi yao
#
#                                                  Title  \
# 0    Poster Securing Distributed System Configurati...
# 1    DeBot Novel Network based Mechanism Detect Exf...
# 2    From Cyber Situational Awareness Adaptive Cybe...
# 3    Quantitative Framework Model Advanced Persiste...
# 4    Defending Stealthy Botnets Using Moving Target...
# ..                                                 ...
# 369  Resolving Contentions Intelligent Traffic Inte...
# ...

# %%
new_stopwords = ["A", "from", "In", "This", "We","-"] # removing Stop Words
stpwrd = nltk.corpus.stopwords.words('english')
stpwrd.extend(new_stopwords)

# %%
stop = stopwords.words('english') #Removing Stopwords

df2 = data3
data3.columns = ["Unnamed: 0","authors","Title","Descriptions","Date","About","Link"]

data3["Title"] = data3["Title"].apply(lambda x: ' '.join([word for word in x.split() if word not in (stpwrd)]))
data3['Descriptions'] = data3['Descriptions'].apply(lambda x: ' '.join([word for word in str(x).split() if word not in (stpwrd)]))
data3['About'] = data3['About'].apply(lambda x: ' '.join([word for word in str(x).split() if word not in (stpwrd)]))

print(data3)
# Out:
#      Unnamed: 0                authors  \
# 0             0  massimiliano albanese
# 1             1  massimiliano albanese
# 2             2  massimiliano albanese
# 3             3  massimiliano albanese
# 4             4  massimiliano albanese
# ..          ...                    ...
# 369         369            ningshi yao
# 370         370            ningshi yao
# 371         371            ningshi yao
# 372         372            ningshi yao
# 373         373            ningshi yao
#
#                                                  Title  \
# 0    Poster Securing Distributed System Configurati...
# 1    DeBot Novel Network based Mechanism Detect Exf...
# 2    From Cyber Situational Awareness Adaptive Cybe...
# 3    Quantitative Framework Model Advanced Persiste...
# 4    Defending Stealthy Botnets Using Moving Target...
# ..                                                 ...
# 369  Resolving Contentions Intelligent Traffic Inte...
# ...

# %%
data3.drop('Unnamed: 0', inplace=True, axis=1) #Dropping Column

# %%
data3['Descriptions'] = data3['Descriptions'].map(lambda x: re.sub(r'\W+', ' ', x)) #Removing Special Characters
data3['Title'] = data3['Title'].map(lambda x: re.sub(r'\W+', ' ', x))
data3['authors'] = data3['authors'].map(lambda x: re.sub(r'\W+', ' ', x))
data3['About'] = data3['About'].str.replace('\W', ' ')

# %%
data3
# Out:
#                    authors                                              Title  \
# 0    massimiliano albanese  Poster Securing Distributed System Configurati...
# 1    massimiliano albanese  DeBot Novel Network based Mechanism Detect Exf...
# 2    massimiliano albanese  From Cyber Situational Awareness Adaptive Cybe...
# 3    massimiliano albanese  Quantitative Framework Model Advanced Persiste...
# 4    massimiliano albanese  Defending Stealthy Botnets Using Moving Target...
# ..                     ...                                                ...
# 369            ningshi yao  Resolving Contentions Intelligent Traffic Inte...
# 370            ningshi yao  Scheduling feasibility energy management micro...
# 371            ningshi yao  Monocular vision based human following miniatu...
# 372            ningshi yao  Contention resolving optimal priority assignme...
# 373            ningshi yao  Modeling effect nanoparticles bistability tran...
#
# ...

# %%
output5 = pd.merge(data1, data3, 
                   on='authors', 
                   how='inner')

# %%
output5
# Out:
#                                                   titles          authors  \
# 0      balancing multiple objectives conformation sam...  ahmed bin zaman
# 1      balancing multiple objectives conformation sam...  ahmed bin zaman
# 2      balancing multiple objectives conformation sam...  ahmed bin zaman
# 3      balancing multiple objectives conformation sam...  ahmed bin zaman
# 4      balancing multiple objectives conformation sam...  ahmed bin zaman
# ...                                                  ...              ...
# 18771                                                            yue wang
# 18772                                                            yue wang
# 18773                                                            yue wang
# 18774                                                            yue wang
# 18775                                                            yue wang
#
#           date                                             source  \
# ...

# %%
data5.to_csv('Final_Consolidated Data1.csv')

# %%
output5.titles.fillna('N/A',inplace=True)

# %%
output5.applymap(lambda x: np.nan if x == '?' else x)
# Out:
#                                                   titles          authors  \
# 0      balancing multiple objectives conformation sam...  ahmed bin zaman
# 1      balancing multiple objectives conformation sam...  ahmed bin zaman
# 2      balancing multiple objectives conformation sam...  ahmed bin zaman
# 3      balancing multiple objectives conformation sam...  ahmed bin zaman
# 4      balancing multiple objectives conformation sam...  ahmed bin zaman
# ...                                                  ...              ...
# 18771                                                            yue wang
# 18772                                                            yue wang
# 18773                                                            yue wang
# 18774                                                            yue wang
# 18775                                                            yue wang
#
#           date                                             source  \
# ...

# %%
import numpy as np

# %%
data5 = data5.fillna('N/A')

# %%
data5
# Out:
#        Unnamed: 0                                             titles  \
# 0               0  balancing multiple objectives conformation sam...
# 1               1  balancing multiple objectives conformation sam...
# 2               2  balancing multiple objectives conformation sam...
# 3               3  balancing multiple objectives conformation sam...
# 4               4  balancing multiple objectives conformation sam...
# ...           ...                                                ...
# 18771       18771
# 18772       18772
# 18773       18773
# 18774       18774
# 18775       18775
#
#                authors     date  \
# 0      ahmed bin zaman  2019/12
# 1      ahmed bin zaman  2019/12
# 2      ahmed bin zaman  2019/12
# 3      ahmed bin zaman  2019/12
# 4      ahmed bin zaman  2019/12
# ...                ...      ...
# 18771         yue wang     2007
# 18772         yue wang     2007
# 18773         yue wang     2007
# 18774         yue wang     2007
# ...

# %%
#loading python require packages
from string import punctuation
from nltk.corpus import stopwords
import nltk
from nltk.stem import WordNetLemmatizer
from IPython.display import display
from nltk.stem import PorterStemmer
import pandas as pd
import os
import numpy as np
from nltk.tokenize import word_tokenize

# %%
#use to remove stop words from sentences
stop_words = set(stopwords.words('english'))

# %%
#function to clean documents
def cleanData(doc):
    tokens = doc.lower().strip().split() #split document into words
    table = str.maketrans('', '', punctuation) #remove punctuation
    tokens = [w.translate(table) for w in tokens]
    tokens = [word for word in tokens if word.isalpha()] #check only for alphabets
    tokens = [w for w in tokens if not w in stop_words] #remove stop words 
    tokens = ' '.join(tokens) #join all words as single document
    return tokens #return cleaned document

# %%
path = 'GoogleScholar'
clean = []
for root, dirs, directory in os.walk(path):#load all documents from GoogleScholar folder
    for j in range(len(directory)):
        document = pd.read_csv(root+"/"+directory[j]) #Read contents from each document 
        document.fillna("N/A", inplace = True)
        for i in range(len(document)): #read all rows from dataset
            titles = str(document.get_value(i, 'titles')) #read each column
            authors = str(document.get_value(i, 'authors'))
            date = str(document.get_value(i, 'date'))
            source = str(document.get_value(i, 'source'))
            desc = str(document.get_value(i, 'descriptions'))
            citations = str(document.get_value(i, 'citations'))
            if len(titles) > 10:
                titles = cleanData(titles) #clean the titles
            if len(source) > 10:    
                source = cleanData(source) #clean source
            if len(desc) > 10:
                desc = cleanData(desc)
            clean.append([titles, authors, date, source, desc, citations]) #add clean data to array    
        print("Cleaned Document Name : "+directory[j]+" "+str(document.shape)+" "+str(len(clean)))          
#create data frame with all cleaned documents    
df = pd.DataFrame(clean, columns = ['titles','authors','date','source','descriptions','citations']) 
df_columns = df.columns
for i in range(len(df_columns)):
    df[df_columns[i]] = df[df_columns[i]].str.lower()
df['titles'] = df['titles'].replace(r'[^a-z//]', ' ', regex=True)
df['descriptions'] = df['descriptions'].replace(r'[^a-z//]', ' ', regex=True)
df['source'] = df['titles'].replace(r'[^a-z//]', ' ', regex=True)
#save and display cleaned document
df.to_csv("Cleaned.csv", index=False)   
print()
print("Cleaned Document")
print()
display(df)
# Out:
# c:\users\munna\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# c:\users\munna\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if __name__ == "__main__":
# c:\users\munna\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.
# c:\users\munna\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # This is added back by InteractiveShellApp.init_path()
# c:\users\munna\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:12: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if sys.path[0] == "":
# c:\users\munna\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:13: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
# Cleaned Document Name : Abbas K Zaidi.csv (52, 6) 52
# Cleaned Document Name : Abolfazl Safikhani.csv (44, 6) 96
# Cleaned Document Name : Aditya Johri.csv (209, 6) 305
# Cleaned Document Name : Ahmed Bin Zaman.csv (13, 6) 318
# Cleaned Document Name : AI Fadahunsi.csv (5, 6) 323
# Cleaned Document Name : Alexander Brodsky.csv (199, 6) 522
# Cleaned Document Name : Alexander Levis.csv (376, 6) 898
# Cleaned Document Name : Ali Beheshti.csv (41, 6) 939
# Cleaned Document Name : Ali Raz.csv (44, 6) 983
# Cleaned Document Name : Amarda Shehu.csv (253, 6) 1236
# Cleaned Document Name : Antonis Anastasopoulos.csv (85, 6) 1321
# Cleaned Document Name : Ariela Sofer.csv (52, 6) 1373
# Cleaned Document Name : Ben Seiyon Lee.csv (17, 6) 1390
# Cleaned Document Name : Bernd-Peter Paris.csv (48, 6) 1438
# Cleaned Document Name : Bijan Jabbari.csv (227, 6) 1665
# Cleaned Document Name : Bo Han.csv (230, 6) 1895
# Cleaned Document Name : Brian L. Mark.csv (183, 6) 2078
# Cleaned Document Name : Brittany I. Johnson.csv (38, 6) 2116
# Cleaned Document Name : Burak Tanyu.csv (82, 6) 2198
# Cleaned Document Name : Cameron Nowzari.csv (65, 6) 2263
# Cleaned Document Name : Carlotta Domeniconi.csv (239, 6) 2502
# Cleaned Document Name : Caroline D Hoemann.csv (140, 6) 2642
# Cleaned Document Name : Celso M Ferreira.csv (155, 6) 2797
# Cleaned Document Name : Colin Reagle.csv (10, 6) 2807
# Cleaned Document Name : Daigo Shishika.csv (37, 6) 2844
# Cleaned Document Name : Daniel Barbara.csv (198, 6) 3042
# Cleaned Document Name : Daniel Menasce.csv (306, 6) 3348
# Cleaned Document Name : Dimitris Ioannou.csv (220, 6) 3568
# Cleaned Document Name : Doaa Bondok.csv (9, 6) 3577
# Cleaned Document Name : Duminda Wijesekera.csv (352, 6) 3929
# Cleaned Document Name : Edward Huang.csv (78, 6) 4007
# Cleaned Document Name : Elise Miller-Hooks.csv (143, 6) 4150
# Cleaned Document Name : Emanuela Marasco.csv (50, 6) 4200
# Cleaned Document Name : Eric Osterweil.csv (113, 6) 4313
# Cleaned Document Name : Eugene Kim.csv (5, 6) 4318
# Cleaned Document Name : Evgenios M. Kornaropoulos.csv (23, 6) 4341
# Cleaned Document Name : Fei Li.csv (67, 6) 4408
# Cleaned Document Name : Foteini Baldimtsi.csv (51, 6) 4459
# Cleaned Document Name : George Hazelrigg.csv (116, 6) 4575
# Cleaned Document Name : Gheorghe Tecuci.csv (209, 6) 4784
# Cleaned Document Name : Giorgio A. Ascoli.csv (308, 6) 5092
# Cleaned Document Name : Giuseppe Ateniese.csv (157, 6) 5249
# Cleaned Document Name : Hadi El-Amine.csv (17, 6) 5266
# Cleaned Document Name : Hakan Aydin.csv (94, 6) 5360
# Cleaned Document Name : Harry Foxwell.csv (7, 6) 5367
# Cleaned Document Name : Hemant Purohit.csv (113, 6) 5480
# Cleaned Document Name : Holger Dannenberg.csv (16, 6) 5496
# Cleaned Document Name : Irina Hashmi.csv (20, 6) 5516
# Cleaned Document Name : Jan Allbeck.csv (101, 6) 5617
# Cleaned Document Name : Janis Terpenny.csv (203, 6) 5820
# Cleaned Document Name : Jeff Offutt.csv (360, 6) 6180
# Cleaned Document Name : Jeffrey Moran.csv (46, 6) 6226
# Cleaned Document Name : Jens-Peter Kaps.csv (83, 6) 6309
# Cleaned Document Name : Jessica Lin.csv (124, 6) 6433
# Cleaned Document Name : Jianli Pan.csv (73, 6) 6506
# Cleaned Document Name : Jie Xu.csv (76, 6) 6582
# Cleaned Document Name : Jim Chen.csv (940, 6) 7522
# Cleaned Document Name : Jinwei Ye.csv (50, 6) 7572
# Cleaned Document Name : John Shortle.csv (88, 6) 7660
# Cleaned Document Name : Jonathan Auerbach.csv (29, 6) 7689
# Cleaned Document Name : Juan Cebral.csv (291, 6) 7980
# Cleaned Document Name : Kai Zeng.csv (160, 6) 8140
# Cleaned Document Name : Karla Hoffman.csv (108, 6) 8248
# Cleaned Document Name : Katherine (Raven) Russell.csv (10, 6) 8258
# Cleaned Document Name : Kenneth S. Ball.csv (115, 6) 8373
# Cleaned Document Name : Kevin Andrea.csv (7, 6) 8380
# Cleaned Document Name : Kevin Lybarger.csv (26, 6) 8406
# Cleaned Document Name : Kevin Moran.csv (49, 6) 8455
# Cleaned Document Name : Khaled N. Khasawneh.csv (39, 6) 8494
# Cleaned Document Name : Khondkar Islam.csv (26, 6) 8520
# Cleaned Document Name : Kim T. Blackwell.csv (152, 6) 8672
# Cleaned Document Name : Kirin Emlet Furst.csv (11, 6) 8683
# Cleaned Document Name : Kris Gaj.csv (229, 6) 8912
# Cleaned Document Name : Kun Sun.csv (142, 6) 9054
# Cleaned Document Name : Kuo Tian.csv (27, 6) 9081
# Cleaned Document Name : Lance Sherry.csv (296, 6) 9377
# Cleaned Document Name : Lannan Lisa Luo.csv (28, 6) 9405
# Cleaned Document Name : Lei Yang.csv (61, 6) 9466
# Cleaned Document Name : Lily Wang.csv (52, 6) 9518
# Cleaned Document Name : Linghan Zhang.csv (13, 6) 9531
# Cleaned Document Name : Lishan Yang.csv (15, 6) 9546
# Cleaned Document Name : Liza Wilson Durant.csv (16, 6) 9562
# Cleaned Document Name : Lucas RF Henneman.csv (47, 6) 9609
# Cleaned Document Name : Mahdi Hashemi.csv (40, 6) 9649
# Cleaned Document Name : Marcos Zampieri.csv (153, 6) 9802
# Cleaned Document Name : Mark Snyder.csv (9, 6) 9811
# Cleaned Document Name : Massimiliano Albanese.csv (126, 6) 9937
# Cleaned Document Name : Md Tanvir Arafin.csv (37, 6) 9974
# Cleaned Document Name : Mehdi Amiri.csv (55, 6) 10029
# Cleaned Document Name : Michael Eagle.csv (60, 6) 10089
# Cleaned Document Name : Michael Lyons.csv (3, 6) 10092
# Cleaned Document Name : Mihai Boicu.csv (132, 6) 10224
# Cleaned Document Name : Mingkui Wei.csv (26, 6) 10250
# Cleaned Document Name : Mingrui Liu.csv (37, 6) 10287
# Cleaned Document Name : Mohan Venigalla.csv (121, 6) 10408
# Cleaned Document Name : Monson Hayes.csv (264, 6) 10672
# Cleaned Document Name : MR Hieb.csv (132, 6) 10804
# Cleaned Document Name : Mulpuri V Rao.csv (236, 6) 11040
# Cleaned Document Name : Myeong Lee.csv (33, 6) 11073
# Cleaned Document Name : Ningshi Yao.csv (15, 6) 11088
# Cleaned Document Name : Omoche Cheche Agada.csv (2, 6) 11090
# Cleaned Document Name : Ozlem Uzuner.csv (93, 6) 11183
# Cleaned Document Name : Parag V. Chitnis.csv (123, 6) 11306
# Cleaned Document Name : Parth Pathak.csv (76, 6) 11382
# Cleaned Document Name : Paul Ammann.csv (148, 6) 11530
# Cleaned Document Name : Pouyan Ahmadi.csv (18, 6) 11548
# Cleaned Document Name : Pramita Bagchi.csv (24, 6) 11572
# Cleaned Document Name : Qi Wei.csv (64, 6) 11636
# Cleaned Document Name : Qiang Zeng.csv (55, 6) 11691
# Cleaned Document Name : Qiliang Li.csv (204, 6) 11895
# Cleaned Document Name : Rajesh Ganesan.csv (86, 6) 11981
# Cleaned Document Name : Ran Ji.csv (15, 6) 11996
# Cleaned Document Name : Remi Veneziano.csv (56, 6) 12052
# Cleaned Document Name : Robert G. Pettit IV.csv (56, 6) 12108
# Cleaned Document Name : Robert Handler.csv (161, 6) 12269
# Cleaned Document Name : S. Dov Gordon.csv (44, 6) 12313
# Cleaned Document Name : Sadegh Torabi.csv (22, 6) 12335
# Cleaned Document Name : Sanjeev Setia.csv (78, 6) 12413
# Cleaned Document Name : Sanmay Das.csv (103, 6) 12516
# Cleaned Document Name : Shani E Ross.csv (15, 6) 12531
# Cleaned Document Name : Sharmin Sultana.csv (20, 6) 12551
# Cleaned Document Name : Sherif Hashem.csv (50, 6) 12601
# Cleaned Document Name : Shuochao Yao.csv (81, 6) 12682
# Cleaned Document Name : Siddhartha Sikdar.csv (180, 6) 12862
# Cleaned Document Name : Songqing Chen.csv (202, 6) 13064
# Cleaned Document Name : Sungsoo Ray Hong.csv (52, 6) 13116
# Cleaned Document Name : ThanhVu H. Nguyen.csv (68, 6) 13184
# Cleaned Document Name : Thomas D. LaToza.csv (100, 6) 13284
# Cleaned Document Name : Tianshu Feng.csv (10, 6) 13294
# Cleaned Document Name : Tolga Soyata.csv (104, 6) 13398
# Cleaned Document Name : Vadim Sokolov.csv (65, 6) 13463
# Cleaned Document Name : Vasiliki Ikonomidou.csv (89, 6) 13552
# Cleaned Document Name : Vijay K. Shah.csv (37, 6) 13589
# Cleaned Document Name : Vivian Genaro Motti.csv (132, 6) 13721
# Cleaned Document Name : Viviana Maggioni.csv (185, 6) 13906
# Cleaned Document Name : Weiwen Jiang.csv (106, 6) 14012
# Cleaned Document Name : Xiang 'Shawn' Chen.csv (82, 6) 14094
# Cleaned Document Name : Xiaokuan Zhang.csv (17, 6) 14111
# Cleaned Document Name : xiaonan guo.csv (34, 6) 14145
# Cleaned Document Name : Xuan Wang.csv (23, 6) 14168
# Cleaned Document Name : Xuesu Xiao.csv (81, 6) 14249
# Cleaned Document Name : Yariv Ephraim.csv (101, 6) 14350
# Cleaned Document Name : Yotam Gingold.csv (58, 6) 14408
# Cleaned Document Name : Yue WANG.csv (79, 6) 14487
# Cleaned Document Name : Zhisheng Yan.csv (45, 6) 14532
# Cleaned Document Name : Ziwei Zhu.csv (26, 6) 14558
# Cleaned Document Name : Ziyu Yao.csv (17, 6) 14575
# Cleaned Document
#                                                   titles           authors  \
# 0      multitechnique approach user identification ke...  syed abbas zaidi
# 1            temporal logic programming using petri nets  syed abbas zaidi
# 2          validation verification decision making rules  syed abbas zaidi
# 3      transforming timed influence nets time sliced ...  syed abbas zaidi
# 4      heuristic approach best sets actions determina...  syed abbas zaidi
# ...                                                  ...               ...
# 14570  proceedings workshop structured unstructured k...          ziyu yao
# 14571  code editing exemplars adaptive multiextent co...          ziyu yao
# 14572  proceedings workshop natural language processi...          ziyu yao
# 14573  advancing natural language interfaces data col...          ziyu yao
# 14574  iec towards interesteliciting neural conversat...          ziyu yao
#
#             date                                             source  \
# 0      10/8/2000  multitechnique approach user identification ke...
# 1         1999/5        temporal logic programming using petri nets
# 2       2/1/1997      validation verification decision making rules
# 3       6/1/2004  transforming timed influence nets time sliced ...
# 4      11/8/2004  heuristic approach best sets actions determina...
# ...          ...                                                ...
# 14570     2022/7  proceedings workshop structured unstructured k...
# 14571   3/4/2022  code editing exemplars adaptive multiextent co...
# 14572     2021/8  proceedings workshop natural language processi...
# 14573       2021  advancing natural language interfaces data col...
# 14574       2019  iec towards interesteliciting neural conversat...
#
#                                             descriptions citations
# 0      legitimate user authentication important part ...     179.0
# 1      methodology modeling temporal timesensitive as...      70.0
# 2      methodology validation verification decision m...      63.0
# 3      paper presents algorithm transforming timed in...      33.0
# 4      paper presents heuristic approach problem find...      32.0
# ...                                                  ...       ...
# 14570                                                n/a       n/a
# 14571  paper considers computer source code editing e...       n/a
# 14572  proliferation programmingrelated platforms git...       n/a
# 14573  natural language provides universal efficient ...       n/a
# 14574  conversational agents need sufficient social s...       n/a
#
# [14575 rows x 6 columns]

# %%
merge = []
scholar = pd.read_csv("Cleaned.csv")
scholar_columns = scholar.columns
all_profiles = pd.read_csv("NewData/profiles_final_all.csv", usecols=['Name','Phone Number', 'Biography','Research Interest', 
                                                                       'Degrees','Profile Link','Email', 'Personal Link'])
all_profiles.fillna("N/A", inplace = True)
profile_columns = all_profiles.columns
for i in range(len(profile_columns)):
    all_profiles[profile_columns[i]] = all_profiles[profile_columns[i]].str.lower()
filtered_list
all_profiles['Biography'] = all_profiles['Biography'].replace(r'[^a-z//]', ' ', regex=True)  
all_profiles['Degrees'] = all_profiles['Degrees'].replace(r'[^a-z//]', ' ', regex=True) 
display(all_profiles)
print()
print("Reading & displaying profile data")
print()
# Out:
#                       Name  Phone Number  \
# 0            sharon adamus  703-993-1511
# 1          leonard adelman  703-993-1624
# 2             omoche agada           n/a
# 3            pouyan ahmadi  703-909-7254
# 4    massimiliano albanese  703-993-1629
# ..                     ...           ...
# 236             qiang zeng           n/a
# 237          linghan zhang           n/a
# 238         xiaokuan zhang           n/a
# 239            yutao zhong  703-993-1773
# 240              ziwei zhu           n/a
#
#                                              Biography  \
# 0    bringing the best talent  building the best pr...
# 1     leonard adelman s research is oriented toward...
# 2     omoche cheche agada s areas of interests incl...
# 3    pouyan ahmadi s research interests include coo...
# 4     massimiliano albanese is an associate profess...
# ..                                                 ...
# 236   dr  qiang zeng is an associate professor in t...
# 237   linghan zhang is an assistant professor of th...
# 238   xiaokuan zhang s research interest include co...
# 239  yutao zhong contributes to research and academ...
# 240   ziwei zhu is broadly interested in data minin...
#
#                                      Research Interest  \
# 0                                    machine learning,
# 1    c4i, decision support systems, human-centered ...
# 2                                                  n/a
# 3                                                  n/a
# 4    entrepreneurship and innovation, information s...
# ..                                                 ...
# 236                                                n/a
# 237                                                n/a
# 238                                                n/a
# 239                                                n/a
# 240                                                n/a
#
#                                                Degrees  \
# 0    phd  computer science   brown university scm  ...
# 1    phd  psychology   university of colorado  boul...
# 2    phd  information technology  george mason univ...
# 3    phd  electrical and computer engineering   geo...
# 4    phd  computer science   engineering   universi...
# ..                                                 ...
# 236  phd  computer science and engineering  penn st...
# 237                                                n/a
# 238  phd  computer science and engineering  ohio st...
# 239                                                n/a
# 240       phd  computer science  texas a m university
#
#                               Profile Link             Email  \
# 0    https://cec.gmu.edu/profiles/scarabal               n/a
# 1    https://cec.gmu.edu/profiles/ladelman  ladelman@gmu.edu
# 2            https://cec.gmu.edu/node/8046    oagada@gmu.edu
# 3     https://cec.gmu.edu/profiles/pahmadi   pahmadi@gmu.edu
# 4    https://cec.gmu.edu/profiles/malbanes  malbanes@gmu.edu
# ..                                     ...               ...
# 236    https://cec.gmu.edu/profiles/qzeng2      zeng@gmu.edu
# 237          https://cec.gmu.edu/node/7096  lzhang37@gmu.edu
# 238  https://cec.gmu.edu/profiles/xzhang46  xzhang46@gmu.edu
# 239    https://cec.gmu.edu/profiles/yzhong    yzhong@gmu.edu
# 240    https://cec.gmu.edu/profiles/zzhu20    zzhu20@gmu.edu
#
#                                       Personal Link
# 0                                               n/a
# 1    http://seor.vse.gmu.edu/faculty/adelman.html\n
# 2                                               n/a
# 3                                               n/a
# 4                   http://csis.gmu.edu/albanese/\n
# ..                                              ...
# 236                     https://cs.gmu.edu/~zeng/\n
# 237              https://mason.gmu.edu/~lzhang37/\n
# 238                                             n/a
# 239                    http://cs.gmu.edu/~yzhong/\n
# 240                                             n/a
#
# [241 rows x 8 columns]
# Reading & displaying profile data

# %%
scholar
# Out:
#                                                   titles           authors  \
# 0      multitechnique approach user identification ke...  syed abbas zaidi
# 1            temporal logic programming using petri nets  syed abbas zaidi
# 2          validation verification decision making rules  syed abbas zaidi
# 3      transforming timed influence nets time sliced ...  syed abbas zaidi
# 4      heuristic approach best sets actions determina...  syed abbas zaidi
# ...                                                  ...               ...
# 14570  proceedings workshop structured unstructured k...          ziyu yao
# 14571  code editing exemplars adaptive multiextent co...          ziyu yao
# 14572  proceedings workshop natural language processi...          ziyu yao
# 14573  advancing natural language interfaces data col...          ziyu yao
# 14574  iec towards interesteliciting neural conversat...          ziyu yao
#
#             date                                             source  \
# 0      10/8/2000  multitechnique approach user identification ke...
# 1         1999/5        temporal logic programming using petri nets
# 2       2/1/1997      validation verification decision making rules
# 3       6/1/2004  transforming timed influence nets time sliced ...
# 4      11/8/2004  heuristic approach best sets actions determina...
# ...          ...                                                ...
# 14570     2022/7  proceedings workshop structured unstructured k...
# 14571   3/4/2022  code editing exemplars adaptive multiextent co...
# 14572     2021/8  proceedings workshop natural language processi...
# 14573       2021  advancing natural language interfaces data col...
# 14574       2019  iec towards interesteliciting neural conversat...
#
#                                             descriptions  citations
# 0      legitimate user authentication important part ...      179.0
# 1      methodology modeling temporal timesensitive as...       70.0
# 2      methodology validation verification decision m...       63.0
# 3      paper presents algorithm transforming timed in...       33.0
# 4      paper presents heuristic approach problem find...       32.0
# ...                                                  ...        ...
# 14570                                                NaN        NaN
# 14571  paper considers computer source code editing e...        NaN
# 14572  proliferation programmingrelated platforms git...        NaN
# 14573  natural language provides universal efficient ...        NaN
# 14574  conversational agents need sufficient social s...        NaN
#
# [14575 rows x 6 columns]

# %%
def ismatched(authors, names):
    index = 0
    flag = False
    for i in range(len(names)):
        if authors.strip().lower() == names[i].strip():
            flag = True
            index = i
            break
    return flag, index

# %%
profiles = all_profiles.values
scholars = scholar.values
profile_auth = []
for i in range(len(scholars)):
    name = str(scholars[i,1])
    flag, index = ismatched(name.strip(), all_profiles['Name'].values)
    if flag:
        profile_auth.append(profiles[index,0])
        merge.append([profiles[index,1], profiles[index,2], profiles[index,3], profiles[index,4], profiles[index,5], profiles[index,6], profiles[index,7]])
    else:
        profile_auth.append(profiles[index,0])
        merge.append(['N/A','N/A','N/A','N/A','N/A','N/A','N/A'])
merge = np.asarray(merge)        
print("Total records in Google Scholar : "+str(scholars.shape[0])+" & Total Columns : "+str(scholars.shape[1]))        
print("Total records merge from Profile Dataset : "+str(merge.shape[0])+" Total merge columns : "+str(merge.shape[1]))
print()
# Out:
# Total records in Google Scholar : 14575 & Total Columns : 6
# Total records merge from Profile Dataset : 14575 Total merge columns : 7

# %%
merge1 = []
consolidated = pd.read_csv("NewData/asc_consolidated_data.csv", encoding='iso-8859-1', usecols=['Article Title','Author', 'Subjects', 'Keywords', 'Abstract'])
consolidated.fillna("N/A", inplace = True)
consolidated_columns = consolidated.columns
for i in range(len(consolidated_columns)):
    consolidated[consolidated_columns[i]] = consolidated[consolidated_columns[i]].str.lower()
consolidated['Article Title'] = consolidated['Article Title'].replace(r'[^a-z//]', ' ', regex=True)  
consolidated['Subjects'] = consolidated['Subjects'].replace(r'[^a-z//]', ' ', regex=True)  
consolidated['Keywords'] = consolidated['Keywords'].replace(r'[^a-z//]', ' ', regex=True)  
consolidated['Abstract'] = consolidated['Abstract'].replace(r'[^a-z//]', ' ', regex=True)  
print()
print("Reading & displaying Consolidated data")
print()
display(consolidated)
# Out:
# Reading & displaying Consolidated data
#                                          Article Title           Author  \
# 0    an empirical evaluation of structured argument...  leonard adelman
# 1               confirmation bias in complex analyses   leonard adelman
# 2    confirmation bias in the analysis of remote se...  leonard adelman
# 3    testing the effectiveness of icons for support...  leonard adelman
# 4    using brunswikian theory and a longitudinal de...  leonard adelman
# ..                                                 ...              ...
# 740  friendly spectrum jamming against mimo eavesdr...   harry wechsler
# 741  impact of jamming attacks on vehicular coopera...   harry wechsler
# 742  physical layer key generation in wireless netw...   harry wechsler
# 743  physical layer multi user key generation in wi...           qi wei
# 744  predicting locality phases for dynamic memory ...           qi wei
#
#                                               Subjects  \
# 0    statistical sampling  participation  sample si...
# 1    experimental design  computer systems  heurist...
# 2    remote sensing  data analysis  prejudices  ele...
# 3    decision making  time pressure  psychological ...
# 4                       decision making  time pressure
# ..                                                 ...
# 740  independent component analysis  wireless commu...
# 741  monte carlo method  adaptive control systems  ...
# 742  wireless channels  reciprocity theorems  wirel...
# 743  wireless sensor networks  multiuser computer s...
# 744  digital signal processing  computer storage de...
#
#                                               Keywords  \
# 0    argument support systems  structured argumenta...
# 1    analysis of competing hypotheses  ach   anchor...
# 2    alternative causes approach  confirmation bias...
# 3    distributed decision making  human computer in...
# 4    adaption  brunswikian theory  team decision ma...
# ..                                                 ...
# 740  energy modulation  friendly jamming  mimo tech...
# 741  cooperative adaptive cruise control  cacc  sec...
# 742  communication system security  jamming  networ...
# 743  lower bound  multiple users  parallel probing ...
# 744  dynamic optimization  locality analysis and op...
#
#                                               Abstract
# 0    some structured argumentation tools employ the...
# 1    most research works investigating the confirma...
# 2    analysis of remote sensing data requires a mix...
# 3    there has been minimal experimentation testing...
# 4    brunswikian theory and a longitudinal design w...
# ..                                                 ...
# 740  friendly spectrum jamming is a flexible scheme...
# 741  cooperative adaptive cruise control  cacc  is ...
# 742  physical layer key generation that exploits re...
# 743  secret key generation by extracting the shared...
# 744  abstract  dynamic data  cache  and memory adap...
#
# [745 rows x 5 columns]

# %%
def isConsolidatematched(authors, names):
    index = 0
    flag = False
    arr = authors.split(",")
    for i in range(len(names)):
        temp = names[i].split(",")
        for k in range(len(temp)):
            temp[k] = temp[k].replace(";","")
        out = bool(set(arr) & set(temp))
        if out:
            flag = True
            index = i
            break
    return flag, index

# %%
consolidate = consolidated.values
author = []
for i in range(len(scholars)):
    name = str(scholars[i,1])
    flag, index = ismatched(name.strip(), consolidated['Author'].values)
    if flag:
        author.append(consolidate[index,1])
        merge1.append([consolidate[index,0], consolidate[index,2]+" "+consolidate[index,3]+" "+consolidate[index,4]])
    else:
        author.append(consolidate[index,1])
        merge1.append(['N/A','N/A'])
merge1 = np.asarray(merge1)        
print("Total records in Google Scholar : "+str(scholars.shape[0])+" & Total Columns : "+str(scholars.shape[1]))        
print("Total records merge from Profile Dataset : "+str(merge.shape[0])+" Total merge columns : "+str(merge.shape[1]))
print("Total records merge from Consolidated Dataset : "+str(merge1.shape[0])+" Total merge columns : "+str(merge1.shape[1]))
print()
# Out:
# Total records in Google Scholar : 14575 & Total Columns : 6
# Total records merge from Profile Dataset : 14575 Total merge columns : 7
# Total records merge from Consolidated Dataset : 14575 Total merge columns : 2

# %%
all_columns = []
for i in range(len(scholar_columns)):
    all_columns.append(scholar_columns[i])
for i in range(1,len(profile_columns)):
    all_columns.append(profile_columns[i])
all_columns.append('Article Title')
all_columns.append('Subjects-Keywords-Abstract')
features = np.column_stack((scholars, merge, merge1))
data = pd.DataFrame(features, columns=all_columns)
bio = data['Biography'].values
for i in range(len(bio)):
    bio[i] = cleanData(bio[i])
data['Biography'] = bio    
data.to_csv("merge.csv", index=False)
display(data)
# Out:
#                                                   titles           authors  \
# 0      multitechnique approach user identification ke...  syed abbas zaidi
# 1            temporal logic programming using petri nets  syed abbas zaidi
# 2          validation verification decision making rules  syed abbas zaidi
# 3      transforming timed influence nets time sliced ...  syed abbas zaidi
# 4      heuristic approach best sets actions determina...  syed abbas zaidi
# ...                                                  ...               ...
# 14570  proceedings workshop structured unstructured k...          ziyu yao
# 14571  code editing exemplars adaptive multiextent co...          ziyu yao
# 14572  proceedings workshop natural language processi...          ziyu yao
# 14573  advancing natural language interfaces data col...          ziyu yao
# 14574  iec towards interesteliciting neural conversat...          ziyu yao
#
#             date                                             source  \
# 0      10/8/2000  multitechnique approach user identification ke...
# 1         1999/5        temporal logic programming using petri nets
# 2       2/1/1997      validation verification decision making rules
# 3       6/1/2004  transforming timed influence nets time sliced ...
# 4      11/8/2004  heuristic approach best sets actions determina...
# ...          ...                                                ...
# 14570     2022/7  proceedings workshop structured unstructured k...
# 14571   3/4/2022  code editing exemplars adaptive multiextent co...
# 14572     2021/8  proceedings workshop natural language processi...
# 14573       2021  advancing natural language interfaces data col...
# 14574       2019  iec towards interesteliciting neural conversat...
#
#                                             descriptions citations  \
# 0      legitimate user authentication important part ...       179
# 1      methodology modeling temporal timesensitive as...        70
# 2      methodology validation verification decision m...        63
# 3      paper presents algorithm transforming timed in...        33
# 4      paper presents heuristic approach problem find...        32
# ...                                                  ...       ...
# 14570                                                NaN       NaN
# 14571  paper considers computer source code editing e...       NaN
# 14572  proliferation programmingrelated platforms git...       NaN
# 14573  natural language provides universal efficient ...       NaN
# 14574  conversational agents need sufficient social s...       NaN
#
#        Phone Number                                          Biography  \
# 0      703-993-1774  instructor abbas zaidi pedagogical approach ch...
# 1      703-993-1774  instructor abbas zaidi pedagogical approach ch...
# 2      703-993-1774  instructor abbas zaidi pedagogical approach ch...
# 3      703-993-1774  instructor abbas zaidi pedagogical approach ch...
# 4      703-993-1774  instructor abbas zaidi pedagogical approach ch...
# ...             ...                                                ...
# 14570           n/a  ziyu yao works natural language processing art...
# 14571           n/a  ziyu yao works natural language processing art...
# 14572           n/a  ziyu yao works natural language processing art...
# 14573           n/a  ziyu yao works natural language processing art...
# 14574           n/a  ziyu yao works natural language processing art...
#
#            Research Interest  \
# 0      systems architecture,
# 1      systems architecture,
# 2      systems architecture,
# 3      systems architecture,
# 4      systems architecture,
# ...                      ...
# 14570                    n/a
# 14571                    n/a
# 14572                    n/a
# 14573                    n/a
# 14574                    n/a
#
#                                                  Degrees  \
# 0      phd  information technology   george mason uni...
# 1      phd  information technology   george mason uni...
# 2      phd  information technology   george mason uni...
# 3      phd  information technology   george mason uni...
# 4      phd  information technology   george mason uni...
# ...                                                  ...
# 14570  phd  computer science and engineering  ohio st...
# 14571  phd  computer science and engineering  ohio st...
# 14572  phd  computer science and engineering  ohio st...
# 14573  phd  computer science and engineering  ohio st...
# 14574  phd  computer science and engineering  ohio st...
#
#                                Profile Link            Email  \
# 0      https://cec.gmu.edu/profiles/szaidi2              n/a
# 1      https://cec.gmu.edu/profiles/szaidi2              n/a
# 2      https://cec.gmu.edu/profiles/szaidi2              n/a
# 3      https://cec.gmu.edu/profiles/szaidi2              n/a
# 4      https://cec.gmu.edu/profiles/szaidi2              n/a
# ...                                     ...              ...
# 14570         https://cec.gmu.edu/node/6866  ziyuyao@gmu.edu
# 14571         https://cec.gmu.edu/node/6866  ziyuyao@gmu.edu
# 14572         https://cec.gmu.edu/node/6866  ziyuyao@gmu.edu
# 14573         https://cec.gmu.edu/node/6866  ziyuyao@gmu.edu
# 14574         https://cec.gmu.edu/node/6866  ziyuyao@gmu.edu
#
#                                     Personal Link Article Title  \
# 0      http://seor.vse.gmu.edu/faculty/zaidi.html           N/A
# 1      http://seor.vse.gmu.edu/faculty/zaidi.html           N/A
# 2      http://seor.vse.gmu.edu/faculty/zaidi.html           N/A
# 3      http://seor.vse.gmu.edu/faculty/zaidi.html           N/A
# 4      http://seor.vse.gmu.edu/faculty/zaidi.html           N/A
# ...                                           ...           ...
# 14570                                         n/a           N/A
# 14571                                         n/a           N/A
# 14572                                         n/a           N/A
# 14573                                         n/a           N/A
# 14574                                         n/a           N/A
#
#       Subjects-Keywords-Abstract
# 0                            N/A
# 1                            N/A
# 2                            N/A
# 3                            N/A
# 4                            N/A
# ...                          ...
# 14570                        N/A
# 14571                        N/A
# 14572                        N/A
# 14573                        N/A
# 14574                        N/A
#
# [14575 rows x 15 columns]

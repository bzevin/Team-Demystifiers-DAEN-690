# %%
pip install PyDictionary
# Out:
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1271 sha256=9071dd5c6ab27085b39b8a33a14f9dc2b6099403c05967ff921dcb51013dc264
#   Stored in directory: c:\users\benny\appdata\local\pip\cache\wheels\73\2b\cb\099980278a0c9a3e57ff1a89875ec07bfa0b6fcbebb9a8cad3
# ...
#   Created wheel for goslate: filename=goslate-1.5.4-py3-none-any.whl size=11595 sha256=4c7c5e2d325e0aba232aa12d47f82c0c667f7eca12644f8ce652d8817a4141d0
#   Stored in directory: c:\users\benny\appdata\local\pip\cache\wheels\ee\5c\9a\23d357c94b883bb9b9928aa61fa98641ac1635d5df3dd4dfef
# Successfully built bs4 goslate
# ...
# Note: you may need to restart the kernel to use updated packages.
#     ERROR: Command errored out with exit status 1:
# ...

# %%
from PyDictionary import PyDictionary
dictionary=PyDictionary("Intelligent","Agents")

# %%
test = ["Hi","Bye"]
dictionary1=PyDictionary(test)
dictionary1.getMeanings()['Hi']['Noun'][0]
# Out:
# 'an expression of greeting'

# %%
dictionary.getMeanings()['']
# Out:
# {'Intelligent': {'Adjective': ['having the capacity for thought and reason especially to a high degree',
#    'possessing sound knowledge',
#    'exercising or showing good judgment',
#    'endowed with the capacity to reason']},
#  'Agents': {'Noun': ['an active and efficient cause; capable of producing a certain effect',
#    'a representative who acts on behalf of other persons or organizations',
#    'a substance that exerts some force or effect',
#    'a businessman who buys or sells for another in exchange for a commission',
#    'any agent or representative of a federal agency or bureau',
#    'the semantic role of the animate entity that instigates or causes the happening denoted by the verb in the clause']}}

# %%
Systems =dictionary.meaning("security")
Systems
# Out:
# {'Noun': ['the state of being free from danger or injury',
#   'defense against financial failure; financial independence',
#   'freedom from anxiety or fear',
#   'a formal declaration that documents a fact of relevance to finance and investment; the holder has a right to receive interest or dividends',
#   'property that your creditor can claim in case you default on your obligation',
#   "a department responsible for the security of the institution's property and workers",
#   'a guarantee that an obligation will be met',
#   'an electrical device that sets off an alarm when someone tries to break in',
#   'measures taken as a precaution against theft or espionage or sabotage etc.']}

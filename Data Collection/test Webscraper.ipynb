# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://cec.gmu.edu/profiles/ladelman'
reqs = requests.get(url)
soup = BeautifulSoup(reqs.text, 'html.parser')
 
urls = []
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# https://www.sucuri.net/?utm_source=firewall_block
# https://sucuri.net/?utm_source=firewall_block
# https://support.sucuri.net/?utm_source=firewall_block
# https://sucuri.net/privacy-policy?utm_source=firewall_block

# %%
from selenium import webdriver
driver = webdriver.PhantomJS()
driver.get("https://wrlc-gm.primo.exlibrisgroup.com/discovery/search?query=creator,contains,Wells%20Linton,AND&tab=Everything&search_scope=MyInst_and_CI&vid=01WRLC_GML:01WRLC_GML&lang=en&mode=advanced&offset=0")
#p_element = driver.find_element_by_id(id_='intro-text')
#print(p_element.text)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14976/1735743160.py in <module>
# ----> 1 from selenium import webdriver
#       2 driver = webdriver.PhantomJS()
#       3 driver.get("https://wrlc-gm.primo.exlibrisgroup.com/discovery/search?query=creator,contains,Wells%20Linton,AND&tab=Everything&search_scope=MyInst_and_CI&vid=01WRLC_GML:01WRLC_GML&lang=en&mode=advanced&offset=0")
#       4 #p_element = driver.find_element_by_id(id_='intro-text')
#       5 #print(p_element.text)
#
# ModuleNotFoundError: No module named 'selenium'

# %%
pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
driver = webdriver.PhantomJS()
driver.get("https://wrlc-gm.primo.exlibrisgroup.com/discovery/search?query=creator,contains,Wells%20Linton,AND&tab=Everything&search_scope=MyInst_and_CI&vid=01WRLC_GML:01WRLC_GML&lang=en&mode=advanced&offset=0")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14976/3530326706.py in <module>
#       1 from selenium import webdriver
# ----> 2 driver = webdriver.PhantomJS()
#       3 driver.get("https://wrlc-gm.primo.exlibrisgroup.com/discovery/search?query=creator,contains,Wells%20Linton,AND&tab=Everything&search_scope=MyInst_and_CI&vid=01WRLC_GML:01WRLC_GML&lang=en&mode=advanced&offset=0")
#
# AttributeError: module 'selenium.webdriver' has no attribute 'PhantomJS'

# %%
pip install webdriver_manager
# Out:
# ...
#
# ...

# %%
url = 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=author%3ALin+author%3AWells&btnG='
reqs = requests.get(url)
soup = BeautifulSoup(reqs.text, 'html.parser')

# %%
test = soup.find("div", {"class": "gs_ai gs_scl gs_ai_chpr"})
  
print(test)
# Out:
# <div class="gs_ai gs_scl gs_ai_chpr"><a class="gs_ai_pho" href="/citations?hl=en&amp;user=SCQc-u0AAAAJ"><span class="gs_rimg gs_pp_sm"><img alt="Lin Wells" height="56" sizes="47px" src="https://scholar.googleusercontent.com/citations?view_op=small_photo&amp;user=SCQc-u0AAAAJ&amp;citpid=1" srcset="https://scholar.googleusercontent.com/citations?view_op=small_photo&amp;user=SCQc-u0AAAAJ&amp;citpid=1 47w,https://scholar.googleusercontent.com/citations?view_op=view_photo&amp;user=SCQc-u0AAAAJ&amp;citpid=1 108w" width="47"/></span></a><div class="gs_ai_t"><h3 class="gs_ai_name"><a href="/citations?hl=en&amp;user=SCQc-u0AAAAJ"><span class="gs_hlt">Lin Wells</span></a></h3><div class="gs_ai_aff">C4I &amp; Cyber Center, George Mason University</div><div class="gs_ai_eml">Verified email at gmu.edu</div><div class="gs_ai_cby">Cited by 312</div><div class="gs_ai_int"><a class="gs_ai_one_int" href="/citations?hl=en&amp;view_op=search_authors&amp;mauthors=label:cybersecurity">cybersecurity</a> <a
# ...

# %%
test1 = soup.find("h3", {"class": "gs_ai_name"})
  
print(test1)
for link in test1.find_all('a'):
    print(link.get('href'))
# Out:
# <h3 class="gs_ai_name"><a href="/citations?hl=en&amp;user=SCQc-u0AAAAJ"><span class="gs_hlt">Lin Wells</span></a></h3>
# /citations?hl=en&user=SCQc-u0AAAAJ

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
  
# Creating an instance
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
service = ChromeService(executable_path=ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)

from selenium.webdriver.common.by import By
driver.get("https://wrlc-gm.primo.exlibrisgroup.com/discovery/search?query=creator,exact,Linton%20Wells,AND&tab=Everything&search_scope=MyInst_and_CI&sortby=rank&vid=01WRLC_GML:01WRLC_GML&lang=en&mode=advanced&offset=0")

# %%
driver.get("https://wrlc-gm.primo.exlibrisgroup.com/discovery/search?query=creator,exact,Linton%20Wells,AND&tab=Everything&search_scope=MyInst_and_CI&sortby=rank&vid=01WRLC_GML:01WRLC_GML&lang=en&mode=advanced&offset=20")
time.sleep(3)
src = driver.page_source
  
   # Now using beautiful soup
soup = BeautifulSoup(src, 'lxml')
results = soup.find("div", {"id": "searchResultsContainer"})
print(results)
# Out:
# <div aria-disabled="false" class="results-container zero-padding search-results-container layout-column" id="searchResultsContainer" layout="column" ng-class="{'search-results-container':$ctrl.isSearchState() &amp;&amp; !$ctrl.detectMobile()}" ng-disabled="search$ctrl.searchInProgress" role="document"><!-- --><div class="list-item-wrapper first-in-page" data-page="Page 3" ng-class="{'menu-open':$ctrl.isExpanded($index), 'item-expanded':$ctrl.isExpanded($index), 'last-item': $last, 'first-in-page':$ctrl.firstInPage($index)}" ng-repeat-start="item in $ctrl.itemlist" role="listitem" style=""><!-- --><div aria-level="2" class="md-subheader _md md-primoExplore-theme" id="searchResultPage3" in-view="$ctrl.onTopOfPageInView($ctrl.calcPage($index), $inview, $inviewInfo)" in-view-options="{generateDirection: true, throttle: 50}" ng-if="::$ctrl.firstInPage($index) &amp;&amp; !($ctrl.searchInfo.total &lt;= $ctrl.pageSize)" role="heading" style="position: sticky; top: 0px; z-index: 2;"> <div cla
# ...

# %%
for link in results.find_all("h3", {"class": "item-title"}):
    data = link.find('a').get('href')
    name = link.get_text()
    print(name)
    print(data.split(" ")[0])
# Out:
# ;  Battle-wise : seeking time-information superiority in networked warfare
# https://wrlc-gm.primo.exlibrisgroup.com/discovery/fulldisplay?docid=alma9946906545904105&context=L&vid=01WRLC_GML:01WRLC_GML&lang=en&search_scope=MyInst_and_CI&adaptor=Local
# ;  Odd Couples: The DoD and NGOs
# https://wrlc-gm.primo.exlibrisgroup.com/discovery/fulldisplay?docid=cdi_proquest_miscellaneous_60320853&context=PC&vid=01WRLC_GML:01WRLC_GML&lang=en&search_scope=MyInst_and_CI&adaptor=Primo
# ;  Implementation of a Methodology for the Prioritizing of Suicide Attacker Recruitment Preferences
# https://wrlc-gm.primo.exlibrisgroup.com/discovery/fulldisplay?docid=cdi_proquest_miscellaneous_36700275&context=PC&vid=01WRLC_GML:01WRLC_GML&lang=en&search_scope=MyInst_and_CI&adaptor=Primo
# ;  Sharing to succeed: lessons from open information-sharing projects in Afghanistan
# ...

# %%
temp = soup.find("div", {"class": "search-toolbar-title layout-row"})
count = temp.find("span", {"class": "results-count"})
print(count.get_text().split('  ')[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18276/993058593.py in <module>
#       1 temp = soup.find("div", {"class": "search-toolbar-title layout-row"})
# ----> 2 count = temp.find("span", {"class": "results-count"})
#       3 print(count.get_text().split('  ')[0])
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
pip install pdfreader
# Out:
# ...
#
# ...
#   Created wheel for pdfreader: filename=pdfreader-0.1.12-py3-none-any.whl size=134793 sha256=d89724e903489b8383284a3bbd62f57854b2b4466698d0e52f728ffc27079824
#   Stored in directory: c:\users\benny\appdata\local\pip\cache\wheels\b1\c9\f4\dd0d4745917f3b424036821ad5db110082951e8c8cc49ceace
# Successfully built pdfreader
# ...

# %%
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\benny\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\abc.zip.
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     C:\Users\benny\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\benny\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     C:\Users\benny\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers\averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     C:\Users\benny\AppData\Roaming\nltk_data...
# ...

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
  
# X = input("Enter first string: ").lower()
# Y = input("Enter second string: ").lower()
X ="I love horror movies"
Y ="Lights out is a horror movie"
  
# tokenization
X_list = word_tokenize(X) 
Y_list = word_tokenize(Y)
  
# sw contains the list of stopwords
sw = stopwords.words('english') 
l1 =[];l2 =[]
  
# remove stop words from the string
X_set = {w for w in X_list if not w in sw} 
Y_set = {w for w in Y_list if not w in sw}
print(X_set)
print(Y_set)
  
# form a set containing keywords of both strings 
rvector = X_set.union(Y_set)
print(rvector)
for w in rvector:
    if w in X_set: l1.append(1) # create a vector
    else: l1.append(0)
    if w in Y_set: l2.append(1)
    else: l2.append(0)
c = 0
  
# cosine formula 
for i in range(len(rvector)):
        c+= l1[i]*l2[i]
cosine = c / float((sum(l1)*sum(l2))**0.5)
print("similarity: ", cosine)
# Out:
# {'movies', 'I', 'horror', 'love'}
# {'movie', 'Lights', 'horror'}
# {'movies', 'I', 'movie', 'horror', 'Lights', 'love'}
# similarity:  0.2886751345948129

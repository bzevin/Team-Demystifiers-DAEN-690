# %%
import pandas as pd

# %% [markdown]
# ### Import datasets: Ben's faculty list and my ASC search results

# %%
faculty_df = pd.read_csv('profiles_final_all.csv') # in sprint 2 folder > data > profiles_final_all.csv
asc_og_df = pd.read_csv('asc_consolidated_data.csv') # in sprint 3 folder > asc_data > asc_consolidated_data.csv

# %% [markdown]
# ### View first 5 rows of datasets

# %%
faculty_df[:5]
# Out:
#    Unnamed: 0  Unnamed: 0.1                   Name  \
# 0           0             0          Sharon Adamus
# 1           1             1        Leonard Adelman
# 2           2             2           Omoche Agada
# 3           3             3          Pouyan Ahmadi
# 4           4             4  Massimiliano Albanese
#
#                                                Title  Phone Number  \
# 0  Associate Dean, Undergraduate Programs, Colleg...  703-993-1511
# 1  Professor, Systems Engineering and Operations ...  703-993-1624
# 2                                Assistant Professor           NaN
# 3                                Assistant Professor  703-909-7254
# 4  Associate Professor, Associate Director at the...  703-993-1629
#
#                                            Biography  \
# 0  Bringing the best talent, building the best pr...
# 1   Leonard Adelman’s research is oriented toward...
# 2   Omoche Cheche Agada's areas of interests incl...
# 3  Pouyan Ahmadi's research interests include coo...
# 4   Massimiliano Albanese is an associate Profess...
#
#                                    Research Interest  \
# 0                                  Machine Learning
# 1  C4I, Decision Support Systems, Human-Centered ...
# 2                                                NaN
# 3                                                NaN
# 4  Entrepreneurship and Innovation, Information S...
#
#                                              Degrees  \
# 0  PhD, Computer Science,  Brown University ScM, ...
# 1  PhD, Psychology,  University of Colorado, Boul...
# 2  PhD, Information Technology, George Mason Univ...
# 3  PhD, Electrical and Computer Engineering,  Geo...
# 4  PhD, Computer Science & Engineering,  Universi...
#
#                                                Links  \
# 0                                                NaN
# 1  mailto:ladelman@gmu.edu http://seor.vse.gmu.ed...
# 2                             mailto:oagada@gmu.edu
# 3                            mailto:pahmadi@gmu.edu
# 4  mailto:malbanes@gmu.edu http://csis.gmu.edu/al...
#
#                             Profile Link
# 0  https://cec.gmu.edu/profiles/scarabal
# 1  https://cec.gmu.edu/profiles/ladelman
# 2          https://cec.gmu.edu/node/8046
# 3   https://cec.gmu.edu/profiles/pahmadi
# 4  https://cec.gmu.edu/profiles/malbanes

# %%
asc_og_df[:5]
# Out:
#                                        Article Title  \
# 0  An Empirical Evaluation of Structured Argument...
# 1             Confirmation Bias in Complex Analyses.
# 2  Confirmation Bias in the Analysis of Remote Se...
# 3  Testing the Effectiveness of Icons for Support...
# 4  Using Brunswikian theory and a longitudinal de...
#
#                                               Author  \
# 0  Adelman, Leonard; Lehner, Paul B.; Cheikes, Br...
# 1  Lehner, Paul Edward; Adelman, Leonard; Cheikes...
# 2  Lehner, Paul Edward; Adelman, Leonard; DiStasi...
# 3   Adelman, Leonard; Miller, Sheryl L.; Yeo, Cedric
# 4  Adelman, Leonard; Miller, Sheryl L.; Henderson...
#
#                                        Journal Title      ISSN  ISBN  \
# 0  IEEE Transactions on Systems, Man & Cybernetic...  10834427   NaN
# 1  IEEE Transactions on Systems, Man & Cybernetic...  10834427   NaN
# 2  IEEE Transactions on Systems, Man & Cybernetic...  10834427   NaN
# 3  IEEE Transactions on Systems, Man & Cybernetic...  10834427   NaN
# 4                                  Acta Psychologica  00016918   NaN
#
#   Publication Date Volume Issue First Page  Page Count  Accession Number  \
# 0          May2007     37     3        340         8.0          24858457
# 1          May2008     38     3        584         9.0          31836666
# 2          Jan2009     39     1        218         9.0          39455810
# 3          Mar2004     34     2        179        11.0          12464409
# 4          Feb2003    112     2        181        26.0           8804129
#
#                              DOI      Publisher  Doctype  \
# 0      10.1109/TSMCA.2007.893488           IEEE  Article
# 1      10.1109/TSMCA.2008.918634           IEEE  Article
# 2     10.1109/TSMCA.2008.2006372           IEEE  Article
# 3      10.1109/TSMCA.2003.819492           IEEE  Article
# 4  10.1016/S0001-6918(02)00082-3  Elsevier B.V.  Article
#
#                                             Subjects  \
# 0  STATISTICAL sampling; PARTICIPATION; SAMPLE si...
# 1  EXPERIMENTAL design; COMPUTER systems; HEURIST...
# 2  REMOTE sensing; DATA analysis; PREJUDICES; ELE...
# 3  DECISION making; TIME pressure; PSYCHOLOGICAL ...
# 4                     DECISION making; TIME pressure
#
#                                             Keywords  \
# 0  Argument support systems; structured argumenta...
# 1  Analysis of competing hypotheses (ACH); anchor...
# 2  Alternative causes approach; confirmation bias...
# 3  Distributed decision making; human-computer in...
# 4  Adaption; Brunswikian theory; Team decision ma...
#
#                                             Abstract  \
# 0  Some structured argumentation tools employ the...
# 1  Most research works investigating the confirma...
# 2  Analysis of remote sensing data requires a mix...
# 3  There has been minimal experimentation testing...
# 4  Brunswikian theory and a longitudinal design w...
#
#                                                PLink
# 0  http://mutex.gmu.edu/login?url=https://search....
# 1  http://mutex.gmu.edu/login?url=https://search....
# 2  http://mutex.gmu.edu/login?url=https://search....
# 3  http://mutex.gmu.edu/login?url=https://search....
# 4  http://mutex.gmu.edu/login?url=https://search....

# %% [markdown]
# ### Split authors in ASC data by semicolon + space and create a single entry per author. Then check for any spaces surrounding names

# %%
split_authors_df = asc_og_df.Author.str.split('; ', expand=True).stack()
full_split_df = asc_og_df.join(pd.Series(index=split_authors_df.index.droplevel(1), data=split_authors_df.values, name='Single_Author'))

# %%
split_authors_list = split_authors_df.to_list()
split_authors_list[:10]
# Out:
# ['Adelman, Leonard',
#  'Lehner, Paul B.',
#  'Cheikes, Brant A.',
#  'Taylor, Mark F.',
#  'Lehner, Paul Edward',
#  'Adelman, Leonard',
#  'Cheikes, Brant A.',
#  'Brown, Mark J.',
#  'Lehner, Paul Edward',
#  'Adelman, Leonard']

# %%
full_split_df[:5]
# Out:
#                                        Article Title  \
# 0  An Empirical Evaluation of Structured Argument...
# 0  An Empirical Evaluation of Structured Argument...
# 0  An Empirical Evaluation of Structured Argument...
# 0  An Empirical Evaluation of Structured Argument...
# 1             Confirmation Bias in Complex Analyses.
#
#                                               Author  \
# 0  Adelman, Leonard; Lehner, Paul B.; Cheikes, Br...
# 0  Adelman, Leonard; Lehner, Paul B.; Cheikes, Br...
# 0  Adelman, Leonard; Lehner, Paul B.; Cheikes, Br...
# 0  Adelman, Leonard; Lehner, Paul B.; Cheikes, Br...
# 1  Lehner, Paul Edward; Adelman, Leonard; Cheikes...
#
#                                        Journal Title      ISSN  ISBN  \
# 0  IEEE Transactions on Systems, Man & Cybernetic...  10834427   NaN
# 0  IEEE Transactions on Systems, Man & Cybernetic...  10834427   NaN
# 0  IEEE Transactions on Systems, Man & Cybernetic...  10834427   NaN
# 0  IEEE Transactions on Systems, Man & Cybernetic...  10834427   NaN
# 1  IEEE Transactions on Systems, Man & Cybernetic...  10834427   NaN
#
#   Publication Date Volume Issue First Page  Page Count  Accession Number  \
# 0          May2007     37     3        340         8.0          24858457
# 0          May2007     37     3        340         8.0          24858457
# 0          May2007     37     3        340         8.0          24858457
# 0          May2007     37     3        340         8.0          24858457
# 1          May2008     38     3        584         9.0          31836666
#
#                          DOI Publisher  Doctype  \
# 0  10.1109/TSMCA.2007.893488      IEEE  Article
# 0  10.1109/TSMCA.2007.893488      IEEE  Article
# 0  10.1109/TSMCA.2007.893488      IEEE  Article
# 0  10.1109/TSMCA.2007.893488      IEEE  Article
# 1  10.1109/TSMCA.2008.918634      IEEE  Article
#
#                                             Subjects  \
# 0  STATISTICAL sampling; PARTICIPATION; SAMPLE si...
# 0  STATISTICAL sampling; PARTICIPATION; SAMPLE si...
# 0  STATISTICAL sampling; PARTICIPATION; SAMPLE si...
# 0  STATISTICAL sampling; PARTICIPATION; SAMPLE si...
# 1  EXPERIMENTAL design; COMPUTER systems; HEURIST...
#
#                                             Keywords  \
# 0  Argument support systems; structured argumenta...
# 0  Argument support systems; structured argumenta...
# 0  Argument support systems; structured argumenta...
# 0  Argument support systems; structured argumenta...
# 1  Analysis of competing hypotheses (ACH); anchor...
#
#                                             Abstract  \
# 0  Some structured argumentation tools employ the...
# 0  Some structured argumentation tools employ the...
# 0  Some structured argumentation tools employ the...
# 0  Some structured argumentation tools employ the...
# 1  Most research works investigating the confirma...
#
#                                                PLink        Single_Author
# 0  http://mutex.gmu.edu/login?url=https://search....     Adelman, Leonard
# 0  http://mutex.gmu.edu/login?url=https://search....      Lehner, Paul B.
# 0  http://mutex.gmu.edu/login?url=https://search....    Cheikes, Brant A.
# 0  http://mutex.gmu.edu/login?url=https://search....      Taylor, Mark F.
# 1  http://mutex.gmu.edu/login?url=https://search....  Lehner, Paul Edward

# %% [markdown]
# ### Change ordering of columns; bring 'Single_Author' column next to original 'Author' column and get rid of the 'Author' column

# %%
full_split_df = full_split_df[['Article Title', 'Author', 'Single_Author', 'Journal Title', 'ISSN', 'ISBN', 
                                'Publication Date', 'Volume', 'Issue', 'First Page', 'Page Count', 'Accession Number',
                                'DOI', 'Publisher', 'Doctype', 'Subjects', 'Keywords', 'Abstract',
                                'PLink']]

# %%
single_author_df = full_split_df.drop('Author', axis=1)

# %%
single_author_df[:5]
# Out:
#                                        Article Title        Single_Author  \
# 0  An Empirical Evaluation of Structured Argument...     Adelman, Leonard
# 0  An Empirical Evaluation of Structured Argument...      Lehner, Paul B.
# 0  An Empirical Evaluation of Structured Argument...    Cheikes, Brant A.
# 0  An Empirical Evaluation of Structured Argument...      Taylor, Mark F.
# 1             Confirmation Bias in Complex Analyses.  Lehner, Paul Edward
#
#                                        Journal Title      ISSN  ISBN  \
# 0  IEEE Transactions on Systems, Man & Cybernetic...  10834427   NaN
# 0  IEEE Transactions on Systems, Man & Cybernetic...  10834427   NaN
# 0  IEEE Transactions on Systems, Man & Cybernetic...  10834427   NaN
# 0  IEEE Transactions on Systems, Man & Cybernetic...  10834427   NaN
# 1  IEEE Transactions on Systems, Man & Cybernetic...  10834427   NaN
#
#   Publication Date Volume Issue First Page  Page Count  Accession Number  \
# 0          May2007     37     3        340         8.0          24858457
# 0          May2007     37     3        340         8.0          24858457
# 0          May2007     37     3        340         8.0          24858457
# 0          May2007     37     3        340         8.0          24858457
# 1          May2008     38     3        584         9.0          31836666
#
#                          DOI Publisher  Doctype  \
# 0  10.1109/TSMCA.2007.893488      IEEE  Article
# 0  10.1109/TSMCA.2007.893488      IEEE  Article
# 0  10.1109/TSMCA.2007.893488      IEEE  Article
# 0  10.1109/TSMCA.2007.893488      IEEE  Article
# 1  10.1109/TSMCA.2008.918634      IEEE  Article
#
#                                             Subjects  \
# 0  STATISTICAL sampling; PARTICIPATION; SAMPLE si...
# 0  STATISTICAL sampling; PARTICIPATION; SAMPLE si...
# 0  STATISTICAL sampling; PARTICIPATION; SAMPLE si...
# 0  STATISTICAL sampling; PARTICIPATION; SAMPLE si...
# 1  EXPERIMENTAL design; COMPUTER systems; HEURIST...
#
#                                             Keywords  \
# 0  Argument support systems; structured argumenta...
# 0  Argument support systems; structured argumenta...
# 0  Argument support systems; structured argumenta...
# 0  Argument support systems; structured argumenta...
# 1  Analysis of competing hypotheses (ACH); anchor...
#
#                                             Abstract  \
# 0  Some structured argumentation tools employ the...
# 0  Some structured argumentation tools employ the...
# 0  Some structured argumentation tools employ the...
# 0  Some structured argumentation tools employ the...
# 1  Most research works investigating the confirma...
#
#                                                PLink
# 0  http://mutex.gmu.edu/login?url=https://search....
# 0  http://mutex.gmu.edu/login?url=https://search....
# 0  http://mutex.gmu.edu/login?url=https://search....
# 0  http://mutex.gmu.edu/login?url=https://search....
# 1  http://mutex.gmu.edu/login?url=https://search....

# %% [markdown]
# ### Create new columns for authors' first and last names; split 'Single_Author' by the comma and space

# %%
single_author_df[['Author_ln', 'Author_fn']] = single_author_df['Single_Author'].str.split(', ', expand=True)
single_author_df[:5]
# Out:
#                                        Article Title        Single_Author  \
# 0  An Empirical Evaluation of Structured Argument...     Adelman, Leonard
# 0  An Empirical Evaluation of Structured Argument...      Lehner, Paul B.
# 0  An Empirical Evaluation of Structured Argument...    Cheikes, Brant A.
# 0  An Empirical Evaluation of Structured Argument...      Taylor, Mark F.
# 1             Confirmation Bias in Complex Analyses.  Lehner, Paul Edward
#
#                                        Journal Title      ISSN  ISBN  \
# 0  IEEE Transactions on Systems, Man & Cybernetic...  10834427   NaN
# 0  IEEE Transactions on Systems, Man & Cybernetic...  10834427   NaN
# 0  IEEE Transactions on Systems, Man & Cybernetic...  10834427   NaN
# 0  IEEE Transactions on Systems, Man & Cybernetic...  10834427   NaN
# 1  IEEE Transactions on Systems, Man & Cybernetic...  10834427   NaN
#
#   Publication Date Volume Issue First Page  Page Count  Accession Number  \
# 0          May2007     37     3        340         8.0          24858457
# 0          May2007     37     3        340         8.0          24858457
# 0          May2007     37     3        340         8.0          24858457
# 0          May2007     37     3        340         8.0          24858457
# 1          May2008     38     3        584         9.0          31836666
#
#                          DOI Publisher  Doctype  \
# 0  10.1109/TSMCA.2007.893488      IEEE  Article
# 0  10.1109/TSMCA.2007.893488      IEEE  Article
# 0  10.1109/TSMCA.2007.893488      IEEE  Article
# 0  10.1109/TSMCA.2007.893488      IEEE  Article
# 1  10.1109/TSMCA.2008.918634      IEEE  Article
#
#                                             Subjects  \
# 0  STATISTICAL sampling; PARTICIPATION; SAMPLE si...
# 0  STATISTICAL sampling; PARTICIPATION; SAMPLE si...
# 0  STATISTICAL sampling; PARTICIPATION; SAMPLE si...
# 0  STATISTICAL sampling; PARTICIPATION; SAMPLE si...
# 1  EXPERIMENTAL design; COMPUTER systems; HEURIST...
#
#                                             Keywords  \
# 0  Argument support systems; structured argumenta...
# 0  Argument support systems; structured argumenta...
# 0  Argument support systems; structured argumenta...
# 0  Argument support systems; structured argumenta...
# 1  Analysis of competing hypotheses (ACH); anchor...
#
#                                             Abstract  \
# 0  Some structured argumentation tools employ the...
# 0  Some structured argumentation tools employ the...
# 0  Some structured argumentation tools employ the...
# 0  Some structured argumentation tools employ the...
# 1  Most research works investigating the confirma...
#
#                                                PLink Author_ln    Author_fn
# 0  http://mutex.gmu.edu/login?url=https://search....   Adelman      Leonard
# 0  http://mutex.gmu.edu/login?url=https://search....    Lehner      Paul B.
# 0  http://mutex.gmu.edu/login?url=https://search....   Cheikes     Brant A.
# 0  http://mutex.gmu.edu/login?url=https://search....    Taylor      Mark F.
# 1  http://mutex.gmu.edu/login?url=https://search....    Lehner  Paul Edward

# %% [markdown]
# ### Get rid of 'Single_Author' column, rearrange authors' first and last name columns towards first few columns of dataframe

# %%
single_author_df = single_author_df[['Article Title', 'Author_fn', 'Author_ln', 'Journal Title', 'ISSN', 'ISBN', 
                                'Publication Date', 'Volume', 'Issue', 'First Page', 'Page Count', 'Accession Number',
                                'DOI', 'Publisher', 'Doctype', 'Subjects', 'Keywords', 'Abstract',
                                'PLink']]
single_author_df[:5]
# Out:
#                                        Article Title    Author_fn Author_ln  \
# 0  An Empirical Evaluation of Structured Argument...      Leonard   Adelman
# 0  An Empirical Evaluation of Structured Argument...      Paul B.    Lehner
# 0  An Empirical Evaluation of Structured Argument...     Brant A.   Cheikes
# 0  An Empirical Evaluation of Structured Argument...      Mark F.    Taylor
# 1             Confirmation Bias in Complex Analyses.  Paul Edward    Lehner
#
#                                        Journal Title      ISSN  ISBN  \
# 0  IEEE Transactions on Systems, Man & Cybernetic...  10834427   NaN
# 0  IEEE Transactions on Systems, Man & Cybernetic...  10834427   NaN
# 0  IEEE Transactions on Systems, Man & Cybernetic...  10834427   NaN
# 0  IEEE Transactions on Systems, Man & Cybernetic...  10834427   NaN
# 1  IEEE Transactions on Systems, Man & Cybernetic...  10834427   NaN
#
#   Publication Date Volume Issue First Page  Page Count  Accession Number  \
# 0          May2007     37     3        340         8.0          24858457
# 0          May2007     37     3        340         8.0          24858457
# 0          May2007     37     3        340         8.0          24858457
# 0          May2007     37     3        340         8.0          24858457
# 1          May2008     38     3        584         9.0          31836666
#
#                          DOI Publisher  Doctype  \
# 0  10.1109/TSMCA.2007.893488      IEEE  Article
# 0  10.1109/TSMCA.2007.893488      IEEE  Article
# 0  10.1109/TSMCA.2007.893488      IEEE  Article
# 0  10.1109/TSMCA.2007.893488      IEEE  Article
# 1  10.1109/TSMCA.2008.918634      IEEE  Article
#
#                                             Subjects  \
# 0  STATISTICAL sampling; PARTICIPATION; SAMPLE si...
# 0  STATISTICAL sampling; PARTICIPATION; SAMPLE si...
# 0  STATISTICAL sampling; PARTICIPATION; SAMPLE si...
# 0  STATISTICAL sampling; PARTICIPATION; SAMPLE si...
# 1  EXPERIMENTAL design; COMPUTER systems; HEURIST...
#
#                                             Keywords  \
# 0  Argument support systems; structured argumenta...
# 0  Argument support systems; structured argumenta...
# 0  Argument support systems; structured argumenta...
# 0  Argument support systems; structured argumenta...
# 1  Analysis of competing hypotheses (ACH); anchor...
#
#                                             Abstract  \
# 0  Some structured argumentation tools employ the...
# 0  Some structured argumentation tools employ the...
# 0  Some structured argumentation tools employ the...
# 0  Some structured argumentation tools employ the...
# 1  Most research works investigating the confirma...
#
#                                                PLink
# 0  http://mutex.gmu.edu/login?url=https://search....
# 0  http://mutex.gmu.edu/login?url=https://search....
# 0  http://mutex.gmu.edu/login?url=https://search....
# 0  http://mutex.gmu.edu/login?url=https://search....
# 1  http://mutex.gmu.edu/login?url=https://search....

# %% [markdown]
# ### Combine authors' first and last names into a single column called 'Author'

# %%
single_author_df['Author'] = single_author_df['Author_fn'] + ' ' + single_author_df['Author_ln']
final_df = single_author_df[['Article Title', 'Author', 'Journal Title', 'ISSN', 'ISBN', 
                                'Publication Date', 'Volume', 'Issue', 'First Page', 'Page Count', 'Accession Number',
                                'DOI', 'Publisher', 'Doctype', 'Subjects', 'Keywords', 'Abstract',
                                'PLink']]
final_df[:5]
# Out:
#                                        Article Title              Author  \
# 0  An Empirical Evaluation of Structured Argument...     Leonard Adelman
# 0  An Empirical Evaluation of Structured Argument...      Paul B. Lehner
# 0  An Empirical Evaluation of Structured Argument...    Brant A. Cheikes
# 0  An Empirical Evaluation of Structured Argument...      Mark F. Taylor
# 1             Confirmation Bias in Complex Analyses.  Paul Edward Lehner
#
#                                        Journal Title      ISSN  ISBN  \
# 0  IEEE Transactions on Systems, Man & Cybernetic...  10834427   NaN
# 0  IEEE Transactions on Systems, Man & Cybernetic...  10834427   NaN
# 0  IEEE Transactions on Systems, Man & Cybernetic...  10834427   NaN
# 0  IEEE Transactions on Systems, Man & Cybernetic...  10834427   NaN
# 1  IEEE Transactions on Systems, Man & Cybernetic...  10834427   NaN
#
#   Publication Date Volume Issue First Page  Page Count  Accession Number  \
# 0          May2007     37     3        340         8.0          24858457
# 0          May2007     37     3        340         8.0          24858457
# 0          May2007     37     3        340         8.0          24858457
# 0          May2007     37     3        340         8.0          24858457
# 1          May2008     38     3        584         9.0          31836666
#
#                          DOI Publisher  Doctype  \
# 0  10.1109/TSMCA.2007.893488      IEEE  Article
# 0  10.1109/TSMCA.2007.893488      IEEE  Article
# 0  10.1109/TSMCA.2007.893488      IEEE  Article
# 0  10.1109/TSMCA.2007.893488      IEEE  Article
# 1  10.1109/TSMCA.2008.918634      IEEE  Article
#
#                                             Subjects  \
# 0  STATISTICAL sampling; PARTICIPATION; SAMPLE si...
# 0  STATISTICAL sampling; PARTICIPATION; SAMPLE si...
# 0  STATISTICAL sampling; PARTICIPATION; SAMPLE si...
# 0  STATISTICAL sampling; PARTICIPATION; SAMPLE si...
# 1  EXPERIMENTAL design; COMPUTER systems; HEURIST...
#
#                                             Keywords  \
# 0  Argument support systems; structured argumenta...
# 0  Argument support systems; structured argumenta...
# 0  Argument support systems; structured argumenta...
# 0  Argument support systems; structured argumenta...
# 1  Analysis of competing hypotheses (ACH); anchor...
#
#                                             Abstract  \
# 0  Some structured argumentation tools employ the...
# 0  Some structured argumentation tools employ the...
# 0  Some structured argumentation tools employ the...
# 0  Some structured argumentation tools employ the...
# 1  Most research works investigating the confirma...
#
#                                                PLink
# 0  http://mutex.gmu.edu/login?url=https://search....
# 0  http://mutex.gmu.edu/login?url=https://search....
# 0  http://mutex.gmu.edu/login?url=https://search....
# 0  http://mutex.gmu.edu/login?url=https://search....
# 1  http://mutex.gmu.edu/login?url=https://search....

# %%
faculty_df[:5]
# Out:
#    Unnamed: 0  Unnamed: 0.1                   Name  \
# 0           0             0          Sharon Adamus
# 1           1             1        Leonard Adelman
# 2           2             2           Omoche Agada
# 3           3             3          Pouyan Ahmadi
# 4           4             4  Massimiliano Albanese
#
#                                                Title  Phone Number  \
# 0  Associate Dean, Undergraduate Programs, Colleg...  703-993-1511
# 1  Professor, Systems Engineering and Operations ...  703-993-1624
# 2                                Assistant Professor           NaN
# 3                                Assistant Professor  703-909-7254
# 4  Associate Professor, Associate Director at the...  703-993-1629
#
#                                            Biography  \
# 0  Bringing the best talent, building the best pr...
# 1   Leonard Adelman’s research is oriented toward...
# 2   Omoche Cheche Agada's areas of interests incl...
# 3  Pouyan Ahmadi's research interests include coo...
# 4   Massimiliano Albanese is an associate Profess...
#
#                                    Research Interest  \
# 0                                  Machine Learning
# 1  C4I, Decision Support Systems, Human-Centered ...
# 2                                                NaN
# 3                                                NaN
# 4  Entrepreneurship and Innovation, Information S...
#
#                                              Degrees  \
# 0  PhD, Computer Science,  Brown University ScM, ...
# 1  PhD, Psychology,  University of Colorado, Boul...
# 2  PhD, Information Technology, George Mason Univ...
# 3  PhD, Electrical and Computer Engineering,  Geo...
# 4  PhD, Computer Science & Engineering,  Universi...
#
#                                                Links  \
# 0                                                NaN
# 1  mailto:ladelman@gmu.edu http://seor.vse.gmu.ed...
# 2                             mailto:oagada@gmu.edu
# 3                            mailto:pahmadi@gmu.edu
# 4  mailto:malbanes@gmu.edu http://csis.gmu.edu/al...
#
#                             Profile Link
# 0  https://cec.gmu.edu/profiles/scarabal
# 1  https://cec.gmu.edu/profiles/ladelman
# 2          https://cec.gmu.edu/node/8046
# 3   https://cec.gmu.edu/profiles/pahmadi
# 4  https://cec.gmu.edu/profiles/malbanes

# %%
faculty_df['Name'][:5]
# Out:
# 0            Sharon Adamus
# 1          Leonard Adelman
# 2             Omoche Agada
# 3            Pouyan Ahmadi
# 4    Massimiliano Albanese
# Name: Name, dtype: object

# %% [markdown]
# ### Check for any potential spaces

# %%
author_list = final_df['Author'].to_list()
author_list[:10]
# Out:
# ['Leonard Adelman',
#  'Paul B. Lehner',
#  'Brant A. Cheikes',
#  'Mark F. Taylor',
#  'Paul Edward Lehner',
#  'Leonard Adelman',
#  'Brant A. Cheikes',
#  'Mark J. Brown',
#  'Paul Edward Lehner',
#  'Leonard Adelman']

# %%
name_list = faculty_df['Name'].to_list()
print(name_list)
# Out:
# ['Sharon Adamus', 'Leonard Adelman', 'Omoche Agada', 'Pouyan Ahmadi', 'Massimiliano Albanese', 'Jan Allbeck', 'Mehdi Amiri Darehbidi', 'Matthew Amissah', 'Paul Ammann', 'Antonios Anastasopoulos', 'Kevin Andrea', 'Md Tanvir Arafin', 'Giorgio Ascoli', 'Giuseppe Ateniese', 'Jonathan L. Auerbach', 'Jean-Pierre Auffret', 'Ivan Avramovic', 'Hakan Aydin', 'Pramita Bagchi', 'Foteini Baldimtsi', 'James Baldo', 'Kenneth Ball', 'Daniel Barbará', 'Ali Beheshti', 'Colleen Berg', 'F Berlin', 'Alok Berry', 'Ahmed Bin Zaman', 'Kim Blackwell', 'Mihai Boicu', 'Doaa Bondok', 'Alexander Brodsky', 'Martha Bushong', 'Christopher A. Carr', 'Juan Cebral', 'Ebrima Ceesay', 'Chun-Hung Chen', 'Jim Chen', 'Songqing Chen', 'Xiang Chen', 'Yue Cheng', 'Parag Chitnis', 'Olcay Ciftci', 'Henry Coffman', 'Holger Dannenberg', 'Sanmay Das', 'Isuru Dassanayake', 'Ping Deng', 'Socrates Dimitriadis', 'Carlotta Domeniconi', 'Liza Wilson Durant', 'Michael Eagle', 'Hadi El-Amine', 'Yariv Ephraim', 'Zelalem Eshete', 'Tokunbo Fadahunsi', 'Tianshu Feng', 'Harry Foxwell', 'Kirin Emlet Furst', 'Krzysztof Gaj', 'Rajesh Ganesan', 'Daniel Garrison', 'Mohamed Gebril', 'Vivian Genaro Motti', 'Yotam Gingold', 'Jonathan Goldman', 'Deborah Goodings', 'Samuel Gordon', 'Xiaonan Guo', 'Bo Han', 'Robert Handler', 'Sherif Hashem', 'Mahdi Hashemi', 'Irina Hashmi', 'Monson Hayes', 'George Hazelrigg', 'Lucas Henneman', 'Michael Hieb', 'Caroline Hoemann', 'Karla Hoffman', 'Michael Holland', 'Ray Hong', 'Moinul Hossain', 'Hans Hoyer', 'Brian Hrolenok', 'Inchi Hu', 'Edward Huang', 'Liling Huang', 'Joy Hughes', 'Brett Hunter', 'Vasiliki Ikonomidou', 'Dimitrios Ioannou', 'Khondkar Islam', 'Bijan Jabbari', 'Ran Ji', 'Weiwen Jiang', 'Brittany Johnson-Matthews', 'Aditya Johri', 'Rochelle Jones', 'Shahnaz Kamberi', 'Jens-Peter Kaps', 'Nathan Kathir', 'Larry Kerschberg', 'Khaled Khasawneh', 'Eugene Kim', 'Evgenios Kornaropoulos', 'Laura Kosoglu', 'Pelin Kurtay', 'Wing Lam', 'Thomas LaToza', 'Ben Seiyon Lee', 'Myeong Lee', 'Alexander Levis', 'Scott Lewis', 'Fei Li', 'Qiliang Li', 'Duoduo Liao', 'Jessica Lin', 'Bo Liu', 'Mingrui Liu', 'Craig Lorie', 'Lisa Luo', 'Songjun Luo ', 'Kevin Lybarger', 'Michael Lyons', 'Tamara Maddox', 'Viviana Maggioni', 'Andrzej Manitius', 'Gino Manzo', 'Emanuela Marasco', 'Brian Mark', 'Wassim Masri', 'Damon McCoy', 'Leigh McCue-Weil', 'John McLaughlin', 'Daniel Menascé', 'Elise Miller-Hooks', 'Celso Moller Ferreira', 'Jeffrey Moran', 'Kevin Moran', 'Riki Morikawa', 'Hamza Mughal', 'Rao V. Mulpuri', 'Thanhvu Nguyen', 'Cameron Nowzari', 'Jeff Offutt', 'Robert Osgood', 'Eric Osterweil', 'John Otten', 'Peter Pachowicz', 'Jianli Pan', 'Bernd-Peter Paris', 'Parth Pathak', 'Robert Pettit', 'Hemant Purohit', 'Arthur (Art) Pyster', 'Wanli Qiao', 'Niloofar Ramezani', 'Huzefa Rangwala', 'Ali K. Raz', 'Colin Reagle', 'Hadi Rezazad', 'Dana Richards', 'Andrew Richardson', 'Nicholas Rios', 'William Rosenberger', 'David S. Rosenblum', 'Shani Ross', 'Katherine Russell', 'Ioulia Rytikova', 'Abolfazl Safikhani', 'Sam Salem', 'Kamaljeet Sanghera', 'Bernard Schmidt', 'Steven Schorling', 'Sanjeev Setia', 'Vijay Shah', 'Sharmin Sultana', 'Amarda Shehu', 'Lance Sherry', 'Daigo Shishika', 'John Shortle', 'Gene Shuman', 'Siddhartha Sikdar', 'Gurdip Singh', 'Martin Slawski', 'Mark Snyder', 'Ariela Sofer', 'Vadim Sokolov', 'Shvetha Soundararajan', 'Tolga Soyata', 'Angelos Stavrou', 'Kenneth Strazzeri', 'John Stufken', 'Jiayang Sun', 'Kun Sun', 'Clifton Sutton', 'Burak Tanyu', 'Gheorghe Tecuci', 'Janis Terpenny', 'Kuo Tian', 'Sadegh Torabi', 'Girum Urgessa', 'Özlem Uzuner', 'Remi Veneziano', 'Mohan Venigalla', 'Anand Vidyashankar', 'Kathleen Wage', 'Lily Wang', 'Xinyuan Wang', 'Xuan Wang', 'Diana Wang', 'Yue Wang', 'Harry Wechsler', 'Mingkui Wei', 'Qi Wei', 'Charles White', 'Elizabeth White', 'Duminda Wijesekera', 'Xuesu Xiao', 'Jie Xu', 'Zhisheng Yan', 'Lei Yang', 'Lishan Yang', 'Ningshi Yao', 'Shuochao Yao', 'Ziyu Yao', 'Grigory Yaroslavtsev', 'Jinwei Ye', 'Christine Alonzo Yee', 'Binqian Yin', 'Sy ...

# %% [markdown]
# ### Filter data based on faculty list from other dataframe

# %%
output_df = final_df[final_df.isin(name_list).any(1)]
output_df[10:20]
# Out:
#                                         Article Title          Author  \
# 10  Applying data redundancy to differential equat...     Paul Ammann
# 11                    Can-Follow Concurrency Control.     Paul Ammann
# 13                                  TRUSTED RECOVERY.     Paul Ammann
# 72  The importance of metadata to assess informati...  Giorgio Ascoli
# 75  Axonal morphometry of hippocampal pyramidal ne...  Giorgio Ascoli
# 86  Covariate Balancing through Naturally Occurrin...  Ivan Avramovic
# 87  An Incremental Server for Scheduling Overloade...     Hakan Aydin
# 88  Dynamic modulation scaling enabled multi-hop t...     Hakan Aydin
# 89  Evaluation framework for energy-aware multipro...     Hakan Aydin
# 90  Exact Fault-Sensitive Feasibility Analysis of ...     Hakan Aydin
#
#                       Journal Title      ISSN  ISBN Publication Date Volume  \
# 10   Annals of Software Engineering  10227091   NaN             1997      4
# 11   IEEE Transactions on Computers  00189340   NaN          Oct2007     56
# 13        Communications of the ACM  00010782   NaN            Jul99     42
# 72           Cell & Tissue Research  0302766X   NaN          Apr2015    360
# 75       Brain Structure & Function  18632653   NaN          Mar2011    216
# 86         Health Services Research  00179124   NaN          Feb2018     53
# 87   IEEE Transactions on Computers  00189340   NaN          Oct2003     52
# 88     Wireless Networks (10220038)  10220038   NaN          Feb2020     26
# 89  Journal of Systems Architecture  13837621   NaN          Sep2019     98
# 90   IEEE Transactions on Computers  00189340   NaN          Oct2007     56
#
#    Issue First Page  Page Count  Accession Number  \
# 10     1         65        13.0           9803764
# 11    10       1425         6.0          26820551
# 13     7         71         5.0          12513677
# 72     1        121         7.0         101805666
# 75     1          1        15.0          58132822
# 86     1        273        20.0         127564141
# 87    10       1347        15.0          11034849
# 88     2       1203        24.0         141475264
# 89   NaN        388        15.0         138270784
# 90    10       1372        15.0          26820547
#
#                              DOI                            Publisher  \
# 10       10.1023/A:1018958526071                      Springer Nature
# 11         10.1109/TC.2007.70761                                 IEEE
# 13         10.1145/306549.306580  Association for Computing Machinery
# 72     10.1007/s00441-014-2103-6                      Springer Nature
# 75     10.1007/s00429-010-0291-8                      Springer Nature
# 86       10.1111/1475-6773.12628                      Wiley-Blackwell
# 87       10.1109/TC.2003.1234531                                 IEEE
# 88    10.1007/s11276-019-02146-9                      Springer Nature
# 89  10.1016/j.sysarc.2019.01.018                        Elsevier B.V.
# 90         10.1109/TC.2007.70739                                 IEEE
#
#             Doctype                                           Subjects  \
# 10          Article  REDUNDANCY in engineering; AUTOMATIC data coll...
# 11          Article  DATABASES; ELECTRONIC information resources; I...
# 13          Article  INFORMATION warfare; INFORMATION technology; C...
# 72          Article  NEURONS; CELL morphology; NEUROMORPHICS; DATA ...
# 75          Article  AXONS; MORPHOMETRICS; HIPPOCAMPUS (Brain); BIO...
# 86  journal article  PROPENSITY score matching; NURSING care facili...
# 87          Article  COMPUTER systems; COMPUTER algorithms; WORKLOA...
# 88          Article  WIRELESS sensor networks; ELECTRIC network top...
# 89          Article  VERNACULAR architecture; MULTIPROCESSORS; ENER...
# 90          Article  ALGORITHMS; LINEAR programming; MATHEMATICAL p...
#
#                                              Keywords  \
# 10                                                NaN
# 11  Can-follow; concurrency control; transaction p...
# 13                                                NaN
# 72  Completeness; Data standards; Digital reconstr...
# 75  Axonal arbors; CA3b; CA3c; Digital morphology;...
# 86  Balancing databases; causal impact; confoundin...
# 87                                                NaN
# 88                                                NaN
# 89  Energy management; Multicore architectures; Re...
# 90  deadline-driven systems; fault tolerance; proc...
#
#                                              Abstract  \
# 10  Data redundancy methods evaluate the output of...
# 11  Can-follow concurrency control permits a trans...
# 13  This article emphasizes that though prevention...
# 72  Digital reconstructions of axonal and dendriti...
# 75  xonal arbors of principal neurons form the bac...
# 86  <bold>Objective: </bold>To provide an alternat...
# 87  Proposes a novel scheduling framework for a re...
# 88  The previous work on connection driven topolog...
# 89  Multiprocessor and multicore architectures are...
# 90  In this paper, we consider the problem of chec...
#
#                                                 PLink
# 10  http://mutex.gmu.edu/login?url=https://search....
# 11  http://mutex.gmu.edu/login?url=https://search....
# 13  http://mutex.gmu.edu/login?url=https://search....
# 72  http://mutex.gmu.edu/login?url=https://search....
# 75  http://mutex.gmu.edu/login?url=https://search....
# 86  http://mutex.gmu.edu/login?url=https://search....
# 87  http://mutex.gmu.edu/login?url=https://search....
# 88  http://mutex.gmu.edu/login?url=https://search....
# 89  http://mutex.gmu.edu/login?url=https://search....
# 90  http://mutex.gmu.edu/login?url=https://search....

# %% [markdown]
# ### Output to .csv

# %%
output_df.to_csv('asc_gmu.csv')
